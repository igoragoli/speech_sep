# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
import torch
from IPython.display import Audio

# %%
from speechbrain.pretrained import SepformerSeparation as separator
from utils import select_random_files, form_pairs_mf, separate_pair, compare_sources_with_predictions

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Generating random pairs

# %%
selected_files_m = select_random_files(files_per_folder=2, seconds_considered=5, specify_sex='M')
selected_files_f = select_random_files(files_per_folder=2, seconds_considered=5, specify_sex='F')
formed_pairs = form_pairs_mf(selected_files_m, selected_files_f)

# %%
formed_pairs = formed_pairs[:3]

# %% [markdown]
# ## Extracting one random pair

# %%
pair = random.sample(formed_pairs, 1)
file1, file2 = pair[0].split('-')

# %% [markdown]
# ## Loading model and separating audios

# %%
if device == torch.device("cuda"):
    model = separator.from_hparams(source="speechbrain/sepformer-whamr", savedir='pretrained_models/sepformer-whamr', run_opts={"device":"cuda"})
else:
    model = separator.from_hparams(source="speechbrain/sepformer-whamr", savedir='pretrained_models/sepformer-whamr')

# %%
mixture, sources, predictions = separate_pair(pair[0], model, device)
[audio1, audio2] = sources
[es1, es2] = predictions

# %% [markdown]
# ## Analyzing results

# %% [markdown]
# ### First prediction

# %%
plt.plot(es1)

# %% [markdown]
# ### Second prediction

# %%
plt.plot(es2)

# %% [markdown]
# ### First source

# %%
plt.plot(audio1)

# %% [markdown]
# ### Second source

# %%
plt.plot(audio2)

# %% [markdown]
# ### Linking sources to corresponding predictions

# %%
set1, set2 = compare_sources_with_predictions(sources, predictions)

# %%
wavfile.write("model_validation_mf/mixture.wav", int(16e3), mixture)
wavfile.write("model_validation_mf/audio1.wav", int(8e3), set1[0])
wavfile.write("model_validation_mf/audio2.wav", int(8e3), set2[0])
wavfile.write("model_validation_mf/es1.wav", int(8e3), set1[1])
wavfile.write("model_validation_mf/es2.wav", int(8e3), set2[1])

# %% [markdown]
# ### Mixture

# %%
Audio("model_validation_mf/mixture.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### First batch of corresponding source and prediction

# %%
Audio("model_validation_mf/audio1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("model_validation_mf/es1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Second batch of corresponding source and prediction

# %%
Audio("model_validation_mf/audio2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("model_validation_mf/es2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
